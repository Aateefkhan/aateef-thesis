# %%
import pandas as pns
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.arima_model import ARIMA
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
without_scaling = pns.read_csv('/root/aateef-thesis/jupyter/csv/without_scaling.csv', parse_dates = [0], index_col = [0])

# %%
without_scaling.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
with_scaling = pns.read_csv('/root/aateef-thesis/jupyter/csv/with_scaling.csv', parse_dates = [0], index_col = [0])

# %%
with_scaling.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
